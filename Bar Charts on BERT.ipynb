# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Sample dataframe creation
df = pd.read_excel('review_table.xlsx')
#     'sentiment': ['Positive', 'Negative', 'Negative', 'Positive', ...],
#     'stars_x': [4.5, 3.0, 2.5, 4.0, ...]
# })
df.head()
# Out:
#    Unnamed: 0             business_id                                  name  \
# 0           0  cxupofYLq46bxBHpKyFwsQ  Wyndham New Orleans - French Quarter
# 1           1  cxupofYLq46bxBHpKyFwsQ  Wyndham New Orleans - French Quarter
# 2           2  hkh5iyDeGLNhu-JUQFRE1Q             Royal Sonesta New Orleans
# 3           3  hkh5iyDeGLNhu-JUQFRE1Q             Royal Sonesta New Orleans
# 4           4  hkh5iyDeGLNhu-JUQFRE1Q             Royal Sonesta New Orleans
#
#             address         city state  postal_code   latitude  longitude  \
# 0  124 Royal Street  New Orleans    LA        70130  29.953713 -90.068526
# 1  124 Royal Street  New Orleans    LA        70130  29.953713 -90.068526
# 2    300 Bourbon St  New Orleans    LA        70130  29.955761 -90.067887
# 3    300 Bourbon St  New Orleans    LA        70130  29.955761 -90.067887
# 4    300 Bourbon St  New Orleans    LA        70130  29.955761 -90.067887
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
categories = ['Below Average', 'Above Average']
sub_categories = ['Negative', 'Positive']

# Assuming these are the probabilities or frequencies you want to plot
# For Below Average: Negative Reviews, Positive Reviews
# For Above Average: Negative Reviews, Positive Reviews
values = np.array([[0.2, 0.8], [0.1, 0.9]])  # Example values

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, values[:, 0], width, label='Negative Reviews', color='r')
rects2 = ax.bar(x + width/2, values[:, 1], width, label='Positive Reviews', color='b')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and review sentiment')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# Function to autolabel bars (optional)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Group categories
categories = ['Closed', 'Open']
# Sub-categories (Review Sentiment)
sub_categories = ['Negative', 'Positive']

# Example probabilities or frequencies for each group and sub-category
# Format: [[Negative, Positive] for Closed, [Negative, Positive] for Open]
values = np.array([[0.3, 0.7], [0.2, 0.8]])  # Replace with your actual values

x = np.arange(len(categories))  # The label locations
width = 0.35  # The width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, values[:, 0], width, label='Negative Reviews', color='r')
rects2 = ax.bar(x + width/2, values[:, 1], width, label='Positive Reviews', color='b')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Probability')
ax.set_title('Review Sentiment by Hotel Status')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# Function to autolabel bars (optional)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
